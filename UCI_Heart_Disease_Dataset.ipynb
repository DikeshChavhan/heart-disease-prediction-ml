# %%
# Unzip the Dataset

# !unzip heart+disease.zip
# Out:
# Archive:  heart+disease.zip
#   inflating: Index
#   inflating: WARNING
#   inflating: ask-detrano
#   inflating: bak
#   inflating: cleve.mod
#   inflating: cleveland.data
#    creating: costs/
#   inflating: costs/Index
#   inflating: costs/heart-disease.README
#   inflating: costs/heart-disease.cost
#   inflating: costs/heart-disease.delay
#   inflating: costs/heart-disease.expense
#   inflating: costs/heart-disease.group
#   inflating: heart-disease.names
#   inflating: hungarian.data
#   inflating: long-beach-va.data
#   inflating: new.data
#   inflating: processed.cleveland.data
#   inflating: processed.hungarian.data
#   inflating: processed.switzerland.data
#   inflating: processed.va.data
#   inflating: reprocessed.hungarian.data
#   inflating: switzerland.data

# %%
# load the data

# %%
import pandas as pd

# The dataset is in a text file and has no header row.
# We need to provide column names based on the dataset description.
# Based on the dataset description (heart-disease.names), the columns are:
# age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, num

column_names = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num']

# Load the data

df1 = pd.read_csv('/content/processed.cleveland.data', names=column_names)

df1
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca thal  num
# 0      3.0  0.0  6.0    0
# ...

# %%
df2 = pd.read_csv('/content/processed.hungarian.data', names=column_names)

df2
# Out:
#      age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0     28    1   2      130  132   0       2     185     0      0.0     ?  ?
# 1     29    1   2      120  243   0       0     160     0      0.0     ?  ?
# 2     29    1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3     30    0   1      170  237   0       1     170     0      0.0     ?  ?
# 4     31    0   2      100  219   0       1     150     0      0.0     ?  ?
# ..   ...  ...  ..      ...  ...  ..     ...     ...   ...      ...   ... ..
# 289   52    1   4      160  331   0       0      94     1      2.5     ?  ?
# 290   54    0   3      130  294   0       1     100     1      0.0     2  ?
# 291   56    1   4      155  342   1       0     150     1      3.0     2  ?
# 292   58    0   2      180  393   0       0     110     1      1.0     2  ?
# 293   65    1   4      130  275   0       1     115     1      1.0     2  ?
#
#     thal  num
# 0      ?    0
# 1      ?    0
# ...

# %%
df3 = pd.read_csv('/content/processed.switzerland.data', names=column_names)

df3
# Out:
#      age  sex  cp trestbps  chol fbs restecg thalach exang oldpeak slope ca  \
# 0     32    1   1       95     0   ?       0     127     0      .7     1  ?
# 1     34    1   4      115     0   ?       ?     154     0      .2     1  ?
# 2     35    1   4        ?     0   ?       0     130     1       ?     ?  ?
# 3     36    1   4      110     0   ?       0     125     1       1     2  ?
# 4     38    0   4      105     0   ?       0     166     0     2.8     1  ?
# ..   ...  ...  ..      ...   ...  ..     ...     ...   ...     ...   ... ..
# 118   70    1   4      115     0   0       1      92     1       0     2  ?
# 119   70    1   4      140     0   1       0     157     1       2     2  ?
# 120   72    1   3      160     0   ?       2     114     0     1.6     2  2
# 121   73    0   3      160     0   0       1     121     0       0     1  ?
# 122   74    1   2      145     0   ?       1     123     0     1.3     1  ?
#
#     thal  num
# 0      ?    1
# 1      ?    1
# ...

# %%
df1
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca thal  num
# 0      3.0  0.0  6.0    0
# ...

# %%
# replace "?" with NA then drop NA

df1 = df1.replace("?", pd.NA).dropna()
df1
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 297  57.0  0.0  4.0     140.0  241.0  0.0      0.0    123.0    1.0      0.2
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
#
#      slope   ca thal  num
# 0      3.0  0.0  6.0    0
# ...

# %%
df2
# Out:
#      age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0     28    1   2      130  132   0       2     185     0      0.0     ?  ?
# 1     29    1   2      120  243   0       0     160     0      0.0     ?  ?
# 2     29    1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3     30    0   1      170  237   0       1     170     0      0.0     ?  ?
# 4     31    0   2      100  219   0       1     150     0      0.0     ?  ?
# ..   ...  ...  ..      ...  ...  ..     ...     ...   ...      ...   ... ..
# 289   52    1   4      160  331   0       0      94     1      2.5     ?  ?
# 290   54    0   3      130  294   0       1     100     1      0.0     2  ?
# 291   56    1   4      155  342   1       0     150     1      3.0     2  ?
# 292   58    0   2      180  393   0       0     110     1      1.0     2  ?
# 293   65    1   4      130  275   0       1     115     1      1.0     2  ?
#
#     thal  num
# 0      ?    0
# 1      ?    0
# ...

# %%
df2 = df2.replace("?", pd.NA).dropna()
df2
# Out:
#      age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 205   47    1   4      150  226   0       0      98     1      1.5     2  0
#
#     thal  num
# 205    7    1

# %%
df3 = df3.replace("?", pd.NA).dropna()
df3
# Out:
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, num]
# Index: []

# %%
# Here we observed that the df1 is best data to train
# so use df1

# %%
df1
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 297  57.0  0.0  4.0     140.0  241.0  0.0      0.0    123.0    1.0      0.2
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
#
#      slope   ca thal  num
# 0      3.0  0.0  6.0    0
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
x = df1.drop("num", axis=1)
y = df1["num"]

# %%
x
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 297  57.0  0.0  4.0     140.0  241.0  0.0      0.0    123.0    1.0      0.2
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
#
#      slope   ca thal
# 0      3.0  0.0  6.0
# ...

# %%
y
# Out:
# 0      0
# 1      2
# 2      1
# 3      0
# 4      0
#       ..
# 297    1
# 298    1
# 299    2
# 300    3
# 301    1
# Name: num, Length: 297, dtype: int64

# %%
# Train Test Split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# model
LR = LogisticRegression()
KNN = KNeighborsClassifier()
DT = DecisionTreeClassifier()
RF = RandomForestClassifier()
SVM = SVC()

# %%
# Traning the models

LR.fit(x_train, y_train)
KNN.fit(x_train, y_train)
DT.fit(x_train, y_train)
RF.fit(x_train, y_train)
SVM.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# SVC()

# %%
# testing the models
y_pred_LR = LR.predict(x_test)
y_pred_KNN = KNN.predict(x_test)
y_pred_DT = DT.predict(x_test)
y_pred_RF = RF.predict(x_test)
y_pred_SVM = SVM.predict(x_test)

# %%
# Evaluate the model

print("Logistic Regression:")
print("Accuracy:", accuracy_score(y_test, y_pred_LR))
print("Classification Report:\n", classification_report(y_test, y_pred_LR))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_LR))
# Out:
# Logistic Regression:
# Accuracy: 0.6666666666666666
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.97      0.88        36
#            1       0.43      0.33      0.38         9
#            2       0.25      0.20      0.22         5
#            3       0.20      0.14      0.17         7
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.67        60
#    macro avg       0.33      0.33      0.33        60
# weighted avg       0.59      0.67      0.62        60
#
# Confusion Matrix:
#  [[35  0  0  1  0]
#  [ 4  3  1  1  0]
#  [ 0  2  1  2  0]
#  [ 3  2  1  1  0]
#  [ 2  0  1  0  0]]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
print("KNeighborsClassifier:")
print("Accuracy:", accuracy_score(y_test, y_pred_KNN))
print("Classification Report:\n", classification_report(y_test, y_pred_KNN))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_KNN))
# Out:
# KNeighborsClassifier:
# Accuracy: 0.5
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.62      0.83      0.71        36
#            1       0.00      0.00      0.00         9
#            2       0.00      0.00      0.00         5
#            3       0.00      0.00      0.00         7
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.50        60
#    macro avg       0.12      0.17      0.14        60
# weighted avg       0.38      0.50      0.43        60
#
# Confusion Matrix:
#  [[30  5  0  1  0]
#  [ 9  0  0  0  0]
#  [ 2  2  0  1  0]
#  [ 5  1  1  0  0]
#  [ 2  1  0  0  0]]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
print("DecisionTreeClassifier:")
print("Accuracy:", accuracy_score(y_test, y_pred_DT))
print("Classification Report:\n", classification_report(y_test, y_pred_DT))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_DT))
# Out:
# DecisionTreeClassifier:
# Accuracy: 0.5166666666666667
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.72      0.80        36
#            1       0.14      0.22      0.17         9
#            2       0.14      0.20      0.17         5
#            3       0.25      0.29      0.27         7
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.52        60
#    macro avg       0.29      0.29      0.28        60
# weighted avg       0.60      0.52      0.55        60
#
# Confusion Matrix:
#  [[26  6  3  1  0]
#  [ 2  2  2  2  1]
#  [ 0  1  1  2  1]
#  [ 1  4  0  2  0]
#  [ 0  1  1  1  0]]

# %%
print("RandomForestClassifier:")
print("Accuracy:", accuracy_score(y_test, y_pred_RF))
print("Classification Report:\n", classification_report(y_test, y_pred_RF))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_RF))
# Out:
# RandomForestClassifier:
# Accuracy: 0.6
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.97      0.88        36
#            1       0.00      0.00      0.00         9
#            2       0.25      0.20      0.22         5
#            3       0.00      0.00      0.00         7
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.60        60
#    macro avg       0.21      0.23      0.22        60
# weighted avg       0.50      0.60      0.54        60
#
# Confusion Matrix:
#  [[35  1  0  0  0]
#  [ 5  0  3  1  0]
#  [ 1  2  1  1  0]
#  [ 2  4  0  0  1]
#  [ 1  1  0  1  0]]

# %%
print("SVC:")
print("Accuracy:", accuracy_score(y_test, y_pred_SVM))
print("Classification Report:\n", classification_report(y_test, y_pred_SVM))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_SVM))
# Out:
# SVC:
# Accuracy: 0.6
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.60      1.00      0.75        36
#            1       0.00      0.00      0.00         9
#            2       0.00      0.00      0.00         5
#            3       0.00      0.00      0.00         7
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.60        60
#    macro avg       0.12      0.20      0.15        60
# weighted avg       0.36      0.60      0.45        60
#
# Confusion Matrix:
#  [[36  0  0  0  0]
#  [ 9  0  0  0  0]
#  [ 5  0  0  0  0]
#  [ 7  0  0  0  0]
#  [ 3  0  0  0  0]]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
# Calculate accuracy scores
accuracy_LR = accuracy_score(y_test, y_pred_LR)
accuracy_KNN = accuracy_score(y_test, y_pred_KNN)
accuracy_DT = accuracy_score(y_test, y_pred_DT)
accuracy_RF = accuracy_score(y_test, y_pred_RF)
accuracy_SVM = accuracy_score(y_test, y_pred_SVM)

# %%
# Create a dictionary of models and their accuracies
model_accuracies = {
    "Logistic Regression": accuracy_LR,
    "KNeighborsClassifier": accuracy_KNN,
    "DecisionTreeClassifier": accuracy_DT,
    "RandomForestClassifier": accuracy_RF,
    "SVC": accuracy_SVM
}

# %%
# Find the model with the highest accuracy
best_model_name = max(model_accuracies, key=model_accuracies.get)
best_model_accuracy = model_accuracies[best_model_name]

print(f"The best model based on accuracy is: {best_model_name} with an accuracy of {best_model_accuracy:.4f}")
# Out:
# The best model based on accuracy is: Logistic Regression with an accuracy of 0.6667

# %%
import matplotlib.pyplot as plt
import seaborn as sns
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
import pickle

# Save the best model to a pickle file
filename = 'best_model.pkl'
pickle.dump(best_model, open(filename, 'wb'))

print(f"Best model saved to {filename}")
# Out:
# Best model saved to best_model.pkl
